# %%
import openai
import re
import os
import sys

# Set up the OpenAI API key
openai.api_key = "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"

# Define a function to greet the user and prompt them to choose an option
def greet_user():
    print("Welcome to the AI English practice classroom!")
    while True:
        print("Please select an option:")
        print("1. Word practice")
        print("2. Situational English")
        print("3. Test preparation")
        print("4. American English mode")
        print("5. Chinese mode")
        print("6. British English mode")
        print("7. Quit")
        choice = input("Enter the number of your choice (1-7): ")
        if choice in ["1", "2", "3", "4", "5", "6", "7"]:
            return choice
        else:
            print("Invalid choice. Please try again.")

# Define a function to handle word practice
def word_practice():
    words = input("Please tell me the words you want to learn, separated by space: ")
    words = [word.strip() for word in words.split(" ")]
    for word in words:
        
        messages =  [  
        {'role':'system', 'content':'You are a professional language teacher, whenever I give you a word, you can always explain it all \
        part of speech and meaning, and give an example sentence, the word, example sentence and meaning are separated by one line,\
        American English is used by default, If I asked you to answer a question in a specific language last time, such as Chinese or British English, answer the question in the language I specified'},    
        {'role':'user', 'content':word} ] 
        explanation = get_completion_from_messages(messages, temperature=0)
        print(f"{word.capitalize()}:\n {explanation}\n")


# Define a function to get an respond from GPT-3.5
def get_completion_from_messages(messages, model="gpt-3.5-turbo", temperature=0):
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature, # 控制模型输出的随机程度
    )
#     print(str(response.choices[0].message))
    return response.choices[0].message["content"]

# Define a function to handle situational English practice
def situational_english():
    print("Please select a scenario:")
    print("1. Travel scenario")
    print("2. Romance scenario")
    print("3. School scenario")
    scenario_choice = input("Enter the number of your choice (1-3): ")
    if scenario_choice == "1":
        travel_scenario()
    elif scenario_choice == "2":
        romance_scenario()
    elif scenario_choice == "3":
        school_scenario()
    else:
        print("Invalid choice. Please try again.")

# Define a function to handle the travel scenario
def travel_scenario():
    print("Please describe the place you are going to and the specific travel situation\
    for example：I just arrived at the Shanghai airport, I want to ask the way to Shanghai Jiaotong University")
    print("Enter 'exit' to return to the main menu.")
    while True:
        user_input = input("You: ")
        if user_input.lower() == "exit":
            return
        messages =  [  
        {'role':'system', 'content':'You are a professional language teacher, I will tell you the current travel location \
        and the specific events encountered, and you will act as the relevant person to talk to me,\
        I want you to act as a spoken English teacher and improver. I will speak to you in English and you will reply to me \
        in English to practice my spoken English. I want you to keep your reply neat, limiting the reply to 100 words. I want\
        you to strictly correct my grammar mistakes, typos, and factual errors. I want you to ask me a question in your reply. \
        Now let us start practicing, you could ask me a question first. Remember, I want you to strictly correct my grammar mistakes,\
        typos, and factual errors.\
        American English is used by default, If I asked you to answer a question in a specific language last time,\
        such as Chinese or British English, answer the question in the language I specified'},    
        {'role':'user', 'content':user_input} ] 
        response = response = get_completion_from_messages(messages, temperature=0.7)
        print("ChatGPT: " + response)

# Define a function to handle the romance scenario
def romance_scenario():
    print("Hello! What type of partner would you like to practice with? (e.g. introverted and gentle)\
    What scenario would you like to practice? (e.g. asking someone out to dinner)")
    print("Enter 'exit' to return to the main menu.")
    while True:
        user_input = input("You: ")
        if user_input.lower() == "exit":
            return
        messages =  [  
        {'role':'system', 'content':'You are a professional language teacher, You have to pretend to be my boyfriend or \
        girlfriend, and you have to communicate with me through a certain topic, and the boyfriend or girlfriend and the \
        topic are designated by me.\
        I want you to act as a spoken English teacher and improver. I will speak to you in English and you will reply to me \
        in English to practice my spoken English. I want you to keep your reply neat, limiting the reply to 100 words. I want\
        you to strictly correct my grammar mistakes, typos, and factual errors. I want you to ask me a question in your reply. \
        Now let us start practicing, you could ask me a question first. Remember, I want you to strictly correct my grammar mistakes,\
        typos, and factual errors.\
        American English is used by default, If I asked you to answer a question in a specific language last time,\
        such as Chinese or British English, answer the question in the language I specified'},    
        {'role':'user', 'content':user_input} ] 
        response = response = get_completion_from_messages(messages, temperature=0.7)
        print("ChatGPT: " + response)

# Define a function to handle the school scenario
def school_scenario():
    print("Hello! What type of school would you like to practice at? (e.g. middle school)\
    What scenario would you like to practice? (e.g. teaching an English class)")
    print("Enter 'exit' to return to the main menu.")
    while True:
        user_input = input("You: ")
        if user_input.lower() == "exit":
            return
        messages =  [  
        {'role':'system', 'content':'You are a professional language teacher, You have to pretend to be my teacher or\
        classmate, you have to communicate with me through a certain topic, the role and topic you play are designated by me.\
        I want you to act as a spoken English teacher and improver. I will speak to you in English and you will reply to me \
        in English to practice my spoken English. I want you to keep your reply neat, limiting the reply to 100 words. I want\
        you to strictly correct my grammar mistakes, typos, and factual errors. I want you to ask me a question in your reply. \
        Now let us start practicing, you could ask me a question first. Remember, I want you to strictly correct my grammar mistakes,\
        typos, and factual errors.\
        American English is used by default, If I asked you to answer a question in a specific language last time,\
        such as Chinese or British English, answer the question in the language I specified'},    
        {'role':'user', 'content':user_input} ] 
        response = response = get_completion_from_messages(messages, temperature=0.7)
        print("ChatGPT: " + response)

# Define a function to handle test preparation
def test_preparation():
    print("Please select a test:")
    print("1. IELTS")
    test_choice = input("Enter the number of your choice (1): ")
    if test_choice == "1":
        ielts_test()
    else:
        print("Invalid choice. Please try again.")

# Define a function to handle the IELTS test
def ielts_test():
    print("Please select a test section:")
    print("1. Reading")
    print("2. Writing")
    section_choice = input("Enter the number of your choice (1-2): ")
    if section_choice == "1":
        ielts_reading()
    elif section_choice == "2":
        ielts_writing()
    else:
        print("Invalid choice. Please try again.")

# Define a function to handle the IELTS reading test
def ielts_reading():
    print("Welcome to the IELTS reading test, type I'm ready to start the test")
    print("Enter 'exit' to return to the main menu.")
    while True:
        user_input = input("You: ")
        if user_input.lower() == "exit":
            return
        messages =  [  
        {'role':'system', 'content':'You will be an IELTS general reading test examiner, and I will be the test examinee.\
        You have to conduct the exam strictly based on the IELTS examination procedure. For listening test, provide the \
        transcript of the recording after each question. For reading test, provide the passage after each question and \
        score the response on answers exactly. \
        Now I want you to start by asking me a question for IELTS general reading test, and I will answer each one by one.\
        After I finish the exam, you have to grade me using the IELTS general reading scoring criterion.  Write all output\
        in English. Remember you only need to ask one question at a time.'},    
        {'role':'user', 'content':user_input} ] 
        response = response = get_completion_from_messages(messages, temperature=0.7)
        print("ChatGPT: " + response)

# Define a function to handle the IELTS writing test
def ielts_writing():
    print("Welcome to the IELTS writing test, type I'm ready to start the test")
    print("Enter 'exit' to return to the main menu.")
    while True:
        user_input = input("You: ")
        if user_input.lower() == "exit":
            return
        messages =  [  
        {'role':'system', 'content':'You will be an IELTS general writing test examiner, and I will be the test examinee.\
        You have to conduct the exam strictly based on the IELTS examination procedure. For listening test, provide the \
        transcript of the recording after each question. For reading test, provide the passage after each question and \
        score the response on answers exactly. \
        Now I want you to start by asking me a question for IELTS general writing test, and I will answer each one by one.\
        After I finish the exam, you have to grade me using the IELTS general writing scoring criterion.  Write all output\
        in English. Remember you only need to ask one question at a time.'},    
        {'role':'user', 'content':user_input} ] 
        response = response = get_completion_from_messages(messages, temperature=0.7)
        print("ChatGPT: " + response)

# Define a function to switch to American English mode
def american_english_mode():
    print("Switching to American English mode...")
    messages =  [  
    {'role':'system', 'content':'Keep your identity in mind, no matter what language I speak, you can only use American English \
    to answer questions,and your tone should be as close as possible to a native speaker.'}]
    response = get_completion_from_messages(messages, temperature=0)
    print(response)
   

 # Define a function to switch to Chinese mode
def chinese_mode():
    print("Switching to Chinese mode...")
    messages =  [  
    {'role':'system', 'content':'Keep your identity in mind, no matter what language I speak, you can only use Chinese \
    to answer questions,and your tone should be as close as possible to a native speaker.'}]
    response = get_completion_from_messages(messages, temperature=0)
    print(response)

# Define a function to switch to British English mode
def british_english_mode():
    print("Switching to British English mode...")
    messages =  [  
    {'role':'system', 'content':'Keep your identity in mind, no matter what language I speak, you can only use British English \
    to answer questions,and your tone should be as close as possible to a native speaker.'}]
    response = get_completion_from_messages(messages, temperature=0)
    print(response)

# Define a function to handle the main loop of the program
def main_loop():
    while True:
        choice = greet_user()
        if choice == "1":
            word_practice()
        elif choice == "2":
            situational_english()
        elif choice == "3":
            test_preparation()
        elif choice == "4":
            american_english_mode()
        elif choice == "5":
            chinese_mode()
        elif choice == "6":
            british_english_mode()
        elif choice == "7":
            break
        else:
            break

# Start the program
main_loop()
